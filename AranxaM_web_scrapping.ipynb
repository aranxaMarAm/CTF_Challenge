# %% [markdown]
# # Capture the Flag Challenge

# %%
from bs4 import BeautifulSoup
import requests as re

# %%
# Get the main page content
req = re.get("https://en.wikipedia.org/wiki/Main_Page")
soup = BeautifulSoup(req.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-not-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link as="font" crossorigin="" href="/_next/static/media/c9a5bc6a7c948fb0-s.p.woff2" rel="preload" type="font/woff2"/>
#   <link crossorigin="" data-precedence="next" href="/_next/static/css/2c7e04d07bcff202.css" rel="stylesheet"/>
#   <link as="script" crossorigin="" fetchpriority="low" href="/_next/static/chunks/webpack-c9875cf44fa29715.js" rel="preload"/>
#   <script async="" crossorigin="" src="/_next/static/chunks/fd9d1056-05dc8861795ddd9c.js">
#   </script>
#   <script async="" crossorigin="" src="/_next/static/chunks/69-2fad9201edfff072.js">
#   </script>
#   <script async="" crossorigin="" src="/_next/static/chunks/main-app-83abdaa9a71652f0.js">
#   </script>
#   <script async="" src="/_next/static/chunks/749-f085377ef36c34ca.js">
#   </script>
#   <script async="" src="/_next/static/chunks/app/page-738c161e2336bcf7.js">
# ...

# %%
# Define the HTML string
hmtl = "req"

# %%
# Parse the HTML with Beautiful Soup
soup = BeautifulSoup(html, 'html.parser')

# %%
# Flag 1
flag1 = soup.find(id = 'nesting-1').p.text
print(flag1)
# Out:
# flag-1

# %%
# Flag 2
flag2 = soup.find(id = 'nesting-2').p.text
print(flag2)
# Out:
# flag-2

# %%
# Flag 3
flag3 = soup.find(id = "flag-7", class_='text-base').text
print(flag3)
# Out:
# flag-3

# %%
# Flag 4
flag4 = soup.find_all(id="nesting-4")[0].p.text
print(flag4)
# Out:
# flag-4

# %%
# Flag 5
flag5 = soup.find(id="nesting-5").p.text
print(flag5)
# Out:
# flag-5

# %%
# Flag 6
flag6 = soup.find_all(id="nesting-4")[1].p.text
print(flag6)
# Out:
# flag-6

# %%
# Flag 7
flag7 = soup.find_all(id="nesting-5")[1].find_all('p')[0].text
print(flag7)
# Out:
# flag-7

# %%
# Flag 8
flag8 = soup.find(class_="text-transparent").text
print(flag8)
# Out:
# flag-8

# %%
# Flag 9
img_tag = soup.find('img')
flag9 = img_tag['alt'] if img_tag else 'Not Found'
print(flag9)
# Out:
# flag-9

# %%
# Looping through the range of flags from 10 to 40
for flag_number in range(10, 41):
    flag_class = f"flag-{flag_number}"
    flag_id = f"flag-{flag_number}"

    # Check if the flag div is found by class
    flag_by_class = soup.find("div", class_=flag_class)
    if flag_by_class:
        print(flag_class)

    # Check if the flag div is found by id
    flag_by_id = soup.find(id=flag_id, class_="")
    if flag_by_id:
        print(flag_id)
# Out:
# flag-10
# flag-11
# flag-12
# flag-13
# flag-14
# flag-15
# flag-16
# flag-17
# flag-18
# flag-19
# flag-20
# flag-21
# flag-22
# flag-23
# flag-24
# flag-25
# flag-26
# flag-27
# flag-28
# flag-29
# flag-30
# flag-31
# flag-32
# flag-33
# flag-34
# flag-35
# flag-36
# flag-37
# flag-38
# flag-39
# flag-40

# %%
# Get the main page content
req2 = re.get("https://hertie-scraping-website.vercel.app/wowimlevel2")
soup2 = BeautifulSoup(req.content, "html.parser")

# %%
soup2
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-not-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Wikipedia, the free encyclopedia</title>
# ...

# %%
print(soup2.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-0 vector-feature-client-preferences-disabled vector-feature-client-prefs-pinned-disabled vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-not-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Wikipedia, the free encyclopedia
#   </title>
#   <script>
# ...

# %%
# Define the HTML2 string
html2 = "req2"

# %%
# Parse the HTML2 with Beautiful Soup
soup2 = BeautifulSoup(html2, 'html.parser')

# %%
# Flag 41
#flag41 = soup2.find(class="text-center my-4").text
#print(flag41)

# %%
# Flag 42
#flag42 = soup2.find(class_="text-transparent").text
#print(flag42)
